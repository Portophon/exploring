# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Packages</a></span></li><li><span><a href="#Load-data-set" data-toc-modified-id="Load-data-set-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Load data set</a></span></li></ul></li><li><span><a href="#Consonant-Stats" data-toc-modified-id="Consonant-Stats-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Consonant Stats</a></span><ul class="toc-item"><li><span><a href="#Total-consonant-stats" data-toc-modified-id="Total-consonant-stats-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Total consonant stats</a></span></li><li><span><a href="#Words-with-consonant-stats" data-toc-modified-id="Words-with-consonant-stats-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Words with consonant stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li><li><span><a href="#CV-Stats" data-toc-modified-id="CV-Stats-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>CV Stats</a></span><ul class="toc-item"><li><span><a href="#Load-dataset" data-toc-modified-id="Load-dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load dataset</a></span></li><li><span><a href="#Total-syllable-stats" data-toc-modified-id="Total-syllable-stats-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Total syllable stats</a></span></li><li><span><a href="#Words-with-syllable-stats" data-toc-modified-id="Words-with-syllable-stats-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Words with syllable stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
import squarify

# %% [markdown]
# ## Load data set

# %%
file_name = "PtLanka_compare.csv"

word_df = pd.read_csv(file_name)
word_df
# Out:
#      Unnamed: 0 SriLanka_creole phonetic_transcription Portuguese_definition  \
# 0             0           Abaço                  abaso                abaixo
# 1             1          Aberçà                abeɾsaː               abraçar
# 2             2          abersà                abeɾsaː               abraçar
# 3             3          aburçá                abuɾsaː               abraçar
# 4             4          Aburcé                abuɾseː             aborrecer
# ..          ...             ...                    ...                   ...
# 969        2499           Virrá                  ʋiraː                 virar
# 970        2501           Vistê                 ʋisteː                vestir
# 971        2502           vistá                 ʋistaː                vestir
# 972        2507           Vizia                  ʋizia                 vigia
# 973        2508           Viziá                 ʋiziaː                vigiar
#
#     Portuguese_IPA English_definition     pos Related_languages  \
# 0        ɐ.ˈbaj.ʃu              below  adverb               NaN
# 1       ɐ.bɾɐ.ˈsaɾ                hug    verb               NaN
# 2       ɐ.bɾɐ.ˈsaɾ                hug    verb               NaN
# 3       ɐ.bɾɐ.ˈsaɾ                hug    verb               NaN
# 4     ɐ.bu.Rɨ.ˈseɾ              annoy    verb               NaN
# ..             ...                ...     ...               ...
# 969        vi.ˈɾaɾ        turn around    verb               NaN
# 970       vɨʃ.ˈtiɾ              dress    verb               NaN
# 971       vɨʃ.ˈtiɾ              dress    verb               NaN
# 972       vi.ˈʒi.ɐ           watchman    verb               NaN
# 973      vi.ˈʒi.aɾ       surveillance    verb               NaN
#
#     pt_related annotations                    sources  \
# 0                      NaN                        NaN
# 1                      NaN  O Bruffador, ii periódico
# 2                      NaN  O Bruffador, ii periódico
# 3                      NaN  O Bruffador, ii periódico
# 4                      NaN                        NaN
# ..                     ...                        ...
# 969                    NaN   O Bruffador, i periódico
# 970                    NaN  O Bruffador, ii periódico
# 971                    NaN  O Bruffador, ii periódico
# 972                    NaN                        NaN
# 973                    NaN                        NaN
#
#                                    original_full_entry  \
# 0                             Abaço, abaixo. P. us. V.
# 1             Aberçà, abersà, aburçá {Br. 2), abraçar.
# 2             Aberçà, abersà, aburçá {Br. 2), abraçar.
# 3             Aberçà, abersà, aburçá {Br. 2), abraçar.
# 4                              Aburcé. Mais us. burcé.
# ..                                                 ...
# 969           Virrà {Br. i), virar. Cfr. tirrá, parra.
# 970  Viste, vista {Br. 2), vestir (t. us.). Visteme...
# 971  Viste, vista {Br. 2), vestir (t. us.). Visteme...
# 972                       Vizia, vigia. Viziá, vigiar.
# 973                                                NaN
#
#     original_Portuguese_definition original_linguistic_notes   page
# 0                           abaixo               pouco usado  135.0
# 1                          abraçar                       NaN  135.0
# 2                          abraçar                       NaN  135.0
# 3                          abraçar                       NaN  135.0
# 4                  Mesmo que burcé                       NaN  135.0
# ..                             ...                       ...    ...
# 969                          virar                       NaN  181.0
# 970                         vestir                       NaN  181.0
# 971                         vestir                       NaN  181.0
# 972                          vigia                       NaN  182.0
# 973                         vigiar                       NaN    NaN
#
# [974 rows x 14 columns]

# %%
word_list = list(word_df["phonetic_transcription"])
word_list = [" ".join(list(str(i))) for i in word_list]
word_list
# Out:
# ['a b a s o',
#  'a b e ɾ s a ː',
#  'a b e ɾ s a ː',
#  'a b u ɾ s a ː',
#  'a b u ɾ s e ː',
#  'a b o ɾ s i d o',
#  'a b s e n s a',
#  'a k a ː',
#  'a s o ɾ a g e',
#  'a d e ː o',
#  'a d i o ː t o',
#  'a d u l t e ː ɾ i a',
#  'a d u l t e ɾ a s a ː o',
#  'a f e s a n',
#  'a ː g o ː',
#  'a g ɾ a d a d o',
#  'a g u a ː',
#  'a g u ʋ a ː',
#  'a i n d e ː',
#  'a l b ɾ e',
#  'a ː l b ɾ i',
#  'a ː l b i ɾ',
#  'a l d i a',
#  'a l e g ɾ a d o',
#  'a l e g ɾ o z o',
#  'a l f a d a',
#  'a l f a ː n d a g o',
#  'a l f i a t o',
#  'a ʎ u m a',
#  'a l a g ɾ e',
#  'a l a g ɾ o z o',
#  'a l e g ɾ i o z o',
#  'a l a g ɾ i a',
#  'a l e g ɾ i',
#  'a l m a ː ɾ i',
#  'a l m a z e m',
#  'a l m o ː s a',
#  'a l u m a d o',
#  'a l u m i n a ː',
#  'a l ʋ e ɾ s a ː o',
#  'a l ʋ o ɾ s a ː',
#  'a l ʋ e ɾ s a ː',
#  'a l ʋ o ɾ o s a ː o',
#  'a l ʋ ɾ o s o',
#  'a m a ɲ a ː o',
#  'a m i ɲ a ː o',
#  'a m i a ː o',
#  'a m i a m',
#  'a m a ɾ o z o',
#  'a m e ɾ o z o',
#  'a m o ɾ o',
#  'a m i s a n',
#  'a m p e ː ɾ',
#  'a n e l a',
#  'a n i m a',
#  'a n k e ɾ a ː',
#  'a n k ɾ a ː',
#  'a p i ɲ a ː',
#  'a k e ː l',
#  'a k e l e',
#  'a ː ɾ i a',
#  'a ɾ i a ː',
#  'a ɾ o s',
#  'a ɾ t i f i s o',
#  'a ː s p e ɾ',
#  'a s p e ɾ d a d e',
#  'a s i t a n t o',
#  'a s t a n t o',
#  'a s i n o',
#  'a s o f ɾ a n',
#  'a t a ː',
#  'a t a ɾ d e',
#  'a t ̠ ʃ a ː',
#  'a t ɾ a m e n t o',
#  'a t ː e ɾ m e z a n',
#  'a u d e ː n s i',
#  'a u d i a',
#  'a ʋ a n t a d ̠ ʒ e m',
#  'a ʋ e ʎ o',
#  'a ʋ e n a ː',
#  'a ʋ o a ː',
#  'a z e ː t e',
#  'a z i e t e',
#  'b a k l a ː',
#  'b a i l o',
#  'b a s e ː z a',
#  'b a n d e j a',
#  'b a r a t o',
#  'b a r e ː',
#  'b a t ɾ a i',
#  'b a t ː a ː',
#  'b a t ː a ʎ o',
#  'b a u t i z a ː',
#  'b e b e ɾ a ː o',
#  'b a b a ɾ a ː o',
#  'b e b ɾ a ː o',
#  'b e ː s o',
#  'b e n s a',
#  'b e n s e ː',
#  'b e n d i s a ː o',
#  'b e n e f i k a s a n',
#  'b e ː n z a',
#  'b e ː n z e ː',
#  'b i d ̠ ʒ a ː',
#  'b i z i g a',
#  'b l a s f e m o z o',
#  'b o ː a',
#  'b o k a d e ː',
#  'b o m',
#  'b o ɾ d e ː',
#  'b o ɾ d i a ː',
#  'b o r e s i d o',
#  'b o u t i k',
#  'b ɾ a n k a',
#  'b ɾ a n d a',
#  'b ɾ a n k e ː z a',
#  'b ɾ a z a ː',
#  'b ɾ e m e l i o',
#  'b ɾ i m e l i o',
#  'b ɾ i m a ʎ o',
#  'b ɾ i m e d ̠ ʒ o',
#  'b ɾ u f a d o ɾ',
#  'b u n a k a',
#  'b u n i t o',
#  'b u ɾ s e ː',
#  'b u ɾ s a ː',
#  'k a b e s a',
#  'k a b e s e ː',
#  'k a b e ʎ o',
#  'k a t ̠ ʃ o ɾ i ɲ o',
#  'k a d e ː',
#  'k a d e ː ɾ a',
#  'k a d i a',
#  'k a i ʃ',
#  'k a ː l i s',
#  'k a l m o',
#  'k a m b i a d o ɾ',
#  'k a n a ː ʎ i',
#  'k a n d e s e ɾ a',
#  'k a n ə s e ɾ a',
#  'k a ː n d i a',
#  'k a n t o',
#  'k a p a s',
#  'k a p t a ː o',
#  'k a p i t a n o',
#  'k a ɾ a ʋ a ː o',
#  'k a ɾ g a ː',
#  'k a ɾ g a s a ː o',
#  'k a ɾ i d a ʋ e l',
#  'k a ɾ i n g e d ̠ ʒ o',
#  'k a ɾ i s t i a',
#  'k a ɾ i s t i',
#  'k a r e s t i a',
#  'k a ɾ t e ː',
#  'k a z i a ː o',
#  'k a s a',
#  'k a s t e l a',
#  'k a s t e l e ː',
#  'k a s t i g a s a ː o',
#  'k a t i ʋ i d a d e',
#  'k a t a ː r',
#  'k a u z o',
#  'k a ʋ a ʎ e ɾ i a',
#  'k a ʋ e l ʲ e ː ɾ o',
#  'k a ʋ e l o',
#  'k a ʋ e ɾ n o',
#  'k a ʃ a',
#  's e n d e ː',
#  's e ɾ e m o n i o',
#  't ̠ ʃ a l o',
#  't ̠ ʃ a ː p e ː',
#  't ̠ ʃ a p e',
#  't ̠ ʃ e ː o',
#  't ̠ ʃ e ː ɾ o',
#  't ̠ ʃ i e ɾ o',
#  't ̠ ʃ i e s t o',
#  't ̠ ʃ i s t o',
#  't ̠ ʃ o k a r e ː a',
#  't ̠ ʃ o k e ɾ i a',
#  't ̠ ʃ o m a ː',
#  't ̠ ʃ o ː m a',
#  's i n k u o',
#  's i n k e ː',
#  'k l a ɾ',
#  'k l a ɾ m e n t e',
#  'k o j d a ː',
#  'k o j d a d o',
#  's o j t a ː',
#  'k o l e i s a ː o',
#  'k o l u m n o',
#  'k o ː m a',
#  'k o m e ː',
#  'k o m b e ɾ s a n',
#  'k o m e d i',
#  'k o m e ː d e ː',
#  'k o m e ɾ a',
#  'k o m e ː ɾ e ː',
#  'k o m e ɾ o',
#  'k o m e i ɾ a',
#  'k o m e ː ɾ i a',
#  'k o m i d a ː',
#  'k o m i d a s a ː o',
#  'k o m e t ː a ː',
#  'k o m i ɲ a ː o',
#  'k o m p a ɲ a m e n   t o',
#  'k o m p a ɲ i m e n t o',
#  'k o m p i ɲ a m e n t o',
#  'k o m t o d o',
#  'k o n ə s e ː',
#  'k o n d i n a ː',
#  'k o n d i n a s a ː o',
#  'k o n f e s a ː o',
#  'k o n f e s o',
#  'k o n f o ɾ m a',
#  'k o n f u n d a ː',
#  'k o n s e k ɾ a s a ː o',
#  'k o n s e l a ː',
#  'k o n s e l a s a ː o',
#  'k o n s a l a s a ː o',
#  'k o n s e l ʲ o',
#  'k o n s i s t a ː',
#  'k o n s t ɾ a n g a ː',
#  'k o n t e n t a d o',
#  'k o n t e ɾ',
#  'k o n t ɾ a i ɾ o',
#  'k o n ʋ e ɾ s a ː o',
#  'k o n ʋ e ɾ t a s a ː o',
#  'k o n ʋ i d a s a ː o',
#  'k o n ʋ i n s a ː',
#  'k o ɾ a d ̠ ʒ e ː',
#  'k o ɾ a d ̠ ʒ o',
#  'k o u ɾ a d ̠ ʒ o',
#  'k o ɾ d a ː',
#  'k o ɾ d i a ː',
#  'k o ɾ d e ː',
#  'k o ɾ o ʋ a ː',
#  'k o ɾ o ʋ e ː',
#  'k o r e i s a ː o',
#  'k o r e n t e ː',
#  'k u r e n t o',
#  'k o r u p t i d o',
#  'k o ː ɾ t o',
#  'k o ː s e',
#  'k o s e ː ɾ',
#  'k o u ɾ a s o',
#  'k ɾ e m',
#  'k ɾ e s e n t a ː',
#  'k ɾ i s e n t a ː',
#  'k ɾ i a n s e ː',
#  'k ɾ i e n s a',
#  'k ɾ i s e ː',
#  'k ɾ i z e ː',
#  'k ɾ u ʋ e l d a d e',
#  'k u i d a d e',
#  'k u i d a s a ː o',
#  'k u i d a n s a',
#  'k u i d a n s e ː',
#  'k u m',
#  'k u m ə s a ː',
#  'k u p a ː',
#  'k u p a s a ː o',
#  'k u ɾ a ː',
#  'k u ɾ a l',
#  'k u z a ː',
#  'k u ː s p i',
#  'k o ː s p i',
#  'k u s t o m a ː',
#  'd a ː d i m o',
#  'd a n a f i k a ː',
#  'd a ɾ t e ː',
#  'd e ɾ t e ː',
#  'd e d i a',
#  'd e k l a ɾ a ː o',
#  'd e i ʃ a',
#  'd e s a',
#  'd e m o ː n i',
#  'd e ː n t o ɾ',
#  'd e z a s p a ɾ a ː',
#  'd e s k a ɾ g a ː',
#  'd e s i',
#  'd e s k o m p e t i d o',
#  'd e s k o n t e n t a d o',
#  'd e s k u i d a s a ː o',
#  'd e s k u i d a n s e ː',
#  'd e z e i d ̠ ʒ o',
#  'd e z e ʎ o',
#  'd e z e i d ̠ ʒ a ː',
#  'd e z e m b a ɾ s a n',
#  'd e z e m p a ɾ a ː',
#  'd e z e m p ɾ a ː',
#  'd e ʃ o n e s t a d e',
#  'd e z i a ː',
#  'd i z i a ː',
#  'd i z i a ː',
#  'd e z i o',
#  'd i z i o',
#  'd e z e m p o ɾ t a d o',
#  'd e z m a z i a s a ː o',
#  'd e s p a d a s a ː',
#  'd e s p o j s',
#  'd e s p ɾ a z a ː',
#  'd e s p ɾ o ʋ e i t o z o',
#  'd e s t ɾ i b u a ː',
#  'd e s t ɾ i b u a s a ː o',
#  'd e s t ɾ i b u s a ː o',
#  'd e s t ɾ u ʋ e ː',
#  'd e s t ɾ u i ʋ e ː',
#  'd e s t ɾ u ʋ a ː',
#  'd e s t ɾ u i a s a ː o',
#  'd e s t ɾ u i ʋ i s a ː o',
#  'd e s t ɾ u k s a ː o',
#  'd e t ː a ː',
#  'd e z o j t e ː',
#  'd i f e ɾ e ː n s i a',
#  'd i z a k o ɾ d a n s e ː',
#  'd i s e ː',
#  'd i s e n d e ː',
#  'd i s e ɾ t o',
#  'd i s e t e',
#  'd i s i p l o',
#  'd i s k o n f i a d o ɾ',
#  'd i s k o n f i a d e i ɾ a',
#  'd i s k o n t e n t o m e n t o',
#  'd i s f i e l',
#  'd i s f i e l d a d o',
#  'd i s f i e l d a d e',
#  'd i z m u e ː',
#  'd i z o b e d e s i d o',
#  'd i s p i d e ː',
#  'd i s p o ː s',
#  'd i s p u t a s a ː o',
#  'd o m i n i a ː o',
#  'd o ː s',
#  'd o u s',
#  'd o z e i ɾ o',
#  'd o u z e i ɾ o',
#  'd o ː z i m o',
#  'd ɾ e i t o',
#  'd ɾ e t o',
#  'd ɾ o m i',
#  'd ɾ o m e ː',
#  'd ɾ u m e ː',
#  'd ɾ o m i s a ː',
#  'd ɾ o m i s a ː',
#  'd u ː k i',
#  'd u k e z e ː',
#  'd u ɾ a n s a',
#  'd u ʋ i d a d e',
#  'd u ʋ i d a n s a',
#  'e g u a l a d o m e n t e',
#  'e m p e ɾ a d o ɾ',
#  'e m p e ɾ d o ɾ',
#  'e m p ɾ e s a d o',
#  'e n s e n s o',
#  'e n f e ɾ n o',
#  'e n g ɾ a t o',
#  'e n d ̠ ʒ o e ʎ o',
#  'e n l u m i n a ː',
#  'e n l u m i a ː',
#  'e n t e i ɾ o',
#  'e n ʋ e ː d ̠ ʒ a',
#  'e n ʋ e d ̠ ʒ e ː',
#  'e n ʋ e ː d ̠ ʒ o',
#  'e n ʋ e i d ̠ ʒ o',
#  'e n ʋ i s t e ː',
#  'e ɾ d a ː ʋ e ː',
#  'e s p e ɾ d i s a ː o',
#  'f a ː b ɾ e',
#  'f a e ː',
#  'f a l t a n s a',
#  'f a m i ʎ a',
#  'f a m i l ʲ e ː',
#  'f a s',
#  'f a ː z e',
#  'f a z e d o',
#  'f a z i d o',
#  'f e i r e ː ɾ o',
#  'f e l i z a m e n t e',
#  'f e m e ː',
#  'f e ː o',
#  'f e u',
#  'f e u d a d e',
#  'f e ɾ a ː o',
#  'f e ɾ i d o',
#  'f e r a ɾ o',
#  'f e s a ː o',
#  'f e s t e ː',
#  'f e t i s e ɾ i a',
#  'f e t i s o',
#  'f e t o',
#  'f i e l d a d e',
#  'f i l ʲ o',
#  'f i ɾ m i d a d e',
#  'f i z g a ː',
#  'f i t e ː',
#  'f l a m a',
#  'f o g a ː',
#  'f o ː l g a',
#  'f o ʎ o',
#  'f o ː ɾ e a',
#  'f o ː ɾ i a',
#  'f o ɾ n e ː',
#  'f o r e ː',
#  'f o ɾ t e l e z e ː',
#  'f o ɾ t e ː z a',
#  'f o ɾ t i f i k a s a ː o',
#  'f ɾ e m o z o',
#  'f ɾ e m o z u ɾ a',
#  'f ɾ e m e z u ɾ a',
#  'f ɾ e m e z o ɾ a',
#  'f ɾ e m a z o ɾ a',
#  'f ɾ e ː s',
#  'f ɾ e s',
#  'f ɾ i u',
#  'f ɾ u ː j t o',
#  'f ɾ u i t o z o',
#  'f u g a ː',
#  'f u d ̠ ʒ e ː',
#  'f u l a',
#  'f u l e ː',
#  'f u m a',
#  'f u n d e m e n t o',
#  'f u n d e ː z a',
#  'f u n d u ɾ a',
#  'f u ɾ t e ː z a',
#  'f u ɾ u d ̠ ʒ e ː',
#  'f u ɾ u d ̠ ʒ a',
#  'g a f i ɲ o t o',
#  'g a ː j l o',
#  'g a n ʲ a ː',
#  'g a l ʲ a ɾ d e ː',
#  'g a ɾ d a ː',
#  'g a ɾ d e s e ː',
#  'g a ɾ d i s e ː',
#  'g u a ɾ d i s e ː',
#  'g a ɾ d e s i m e n t o',
#  'g a ɾ d i s e m e n t o',
#  'g a ɾ d i a m e n t o',
#  'd ̠ ʒ e ɾ e z a n',
#  'g o l d i s a ː',
#  'g o t i a ː',
#  'g ɾ a n',
#  'g ɾ e d ̠ ʒ a',
#  'g ɾ i d ̠ ʒ o',
#  'g e r a ː',
#  'a ɾ p o',
#  'e ɾ d a n s a',
#  'e ɾ e d ̠ ʒ i a',
#  'e ɾ e s i a',
#  'e ɾ i d a ː',
#  'i s t o ː ɾ e ː',
#  'o d ̠ ʒ o',
#  'o ː d ̠ ʒ o e',
#  'o m e',
#  'o m i',
#  'o m i s i d o',
#  'o n e s t e',
#  'u m i l d o',
#  'u m i l d e z a',
#  'u m i l i a s a ː o',
#  'i d o l a t e i ɾ o',
#  'i d o l o t e i ɾ o',
#  'i l ʲ a',
#  'i m a d ̠ ʒ o',
#  'i m p i o z o',
#  'i m p o ɾ t a d o',
#  'i m p o ɾ t a n s a',
#  'i m p ɾ e s a d o',
#  'i m p ɾ e s a d o ɾ',
#  'i m p u ɾ i d a d e',
#  'i n f ɾ u i t o z o',
#  'i n g ɾ e s',
#  'i n d ̠ ʒ o e ʎ o',
#  'i n d ̠ ʒ i ʋ e ʎ o',
#  'i n d ̠ ʒ e ʋ e d ̠ ʒ o',
#  'i n d ̠ ʒ i ʋ e d ̠ ʒ o',
#  'i n s t ɾ u i s a ː o',
#  'i n t e ɾ g ɾ i d a d e',
#  'i n t ɾ u d i s a ː o',
#  'i n ʋ e i d ̠ ʒ o',
#  'i ɾ e m a ː o',
#  'i ɾ m a n a',
#  'i s t o ː ɾ i',
#  'd ̠ ʒ a ː',
#  'd ̠ ʒ a ː s p e ɾ',
#  'd ̠ ʒ a ʋ i',
#  'd ̠ ʒ a ʋ i t e m',
#  'd ̠ ʒ i n d ̠ ʒ u ː a',
#  'd ̠ ʒ i n u ː a',
#  'd ̠ ʒ i n d ̠ ʒ u n a s a ː o',
#  'd ̠ ʒ i n d ̠ ʒ u a ː',
#  'd ̠ ʒ o ɾ n a d o',
#  'd ̠ ʒ u d a ː',
#  'd ̠ ʒ u d e ː',
#  'd ̠ ʒ u d a n s a',
#  'd ̠ ʒ u n t a s a ː o',
#  'd ̠ ʒ u n t o   s e ɾ ʋ i d o ɾ',
#  'd ̠ ʒ u s t a ː',
#  'd ̠ ʒ u s t i s i a',
#  'k o k e i ɾ a',
#  'l a d i ɲ a',
#  'l a g a ː ɾ e ː',
#  'l a ː g ɾ i',
#  'l a ː g i ɾ',
#  'l a m p o',
#  'l a n t a ː',
#  'l a s t i m o',
#  'l a s t ɾ o',
#  'l a ː s t o ɾ',
#  'l e g o',
#  'l e a g o u',
#  'l e i',
#  'l e ː s',
#  'l e s',
#  'l e i s',
#  'l e ː s',
#  'l e s t e m e n t e',
#  'l e ː t e',
#  'l e ʋ a d u ɾ a',
#  'l e ʋ e n t a ː',
#  'l i n g o',
#  'l i ʋ e ɾ d a d e',
#  'l i ʋ ɾ a d a d e',
#  'l i ʋ ɾ a n s a',
#  'l i ʋ ɾ a n s e ː',
#  'l i ʋ ɾ a s a ː o',
#  'l o ː',
#  'l o j t a ː',
#  'l o u ʋ ɾ o',
#  'l o ʋ a ː',
#  'l u g a ː ɾ a',
#  'i u g a ː ɾ e ː',
#  'i u g a ː ɾ i a',
#  'l u g e ː ɾ a',
#  'l u m a d o',
#  'l u z e ː',
#  'm a s a ː o',
#  'm a d e ɾ g a ː',
#  'm a g o ʋ a ː',
#  'm a g u ʋ a ː',
#  'm a i',
#  'm a d ̠ ʒ o ɾ',
#  'm a l f e t o ɾ',
#  'm a l i n o',
#  'm a ɲ a ː o',
#  'm a ɲ e s e ː',
#  'm a n e s e ː',
#  'm a ː ɾ a',
#  'm a ɾ e ː',
#  'm a ɾ e l o',
#  'm a ɾ g a',
#  'm a ɾ g o ː ɾ a',
#  'm a ː ɾ m o ɾ',
#  'm a ː ɾ m a ɾ',
#  'm a ɾ t e l e ː',
#  'm a ɾ t e ː l',
#  'm a ɾ ʋ i o z o',
#  'm a t a s a ː o',
#  'm a t a n s a',
#  'm e d e ː',
#  'm e i d o',
#  'm e l i f l u o z o',
#  'm e m o',
#  'm e ː o',
#  'm e ɾ s e ː',
#  'm e ɾ e s e ː',
#  'm e ɾ i t o ː ɾ i a',
#  'm e ː s',
#  'm e ː j s',
#  'm e ː s a',
#  'm e s a ː',
#  'm i l i t a ː ɾ i o',
#  'm i m o ː ɾ i',
#  'm i n i s t e i ɾ o',
#  'm i n i s t ɾ a s a ː o',
#  'm i n t e i ɾ a',
#  'm i ɾ a',
#  'm i z a ɾ a ʋ e l',
#  'm i z ɾ a ʋ e l',
#  'm i z ɾ i k o ɾ d i a',
#  'm i z ɾ e k o ɾ d i a',
#  'm i s t ɾ a ː',
#  'm o j t o',
#  'm o n t a ɲ o',
#  'm o r a',
#  'm o ɾ t a d ̠ ʒ o',
#  'm o ɾ t i a ː',
#  'm o s t a ː ɾ d e ː',
#  'm o u ɾ d e ː',
#  'm o ʋ a ː',
#  'm u e ː',
#  'm u a ː',
#  'm u d a ː n s e ː',
#  'm u d a s a ː o',
#  'm u d a n o',
#  'm u n d o z o',
#  'm u ɾ g i a ː',
#  'm u s t ɾ a ː',
#  'm i s t e ː ɾ i a',
#  'n a n',
#  'n a ʋ i g a ː',
#  'n e s e s t a d e',
#  'n e g o ː s i a',
#  'n i s t a ː',
#  'n i s t a d e',
#  'n o ː',
#  'n u o ː',
#  'n o ː b e ɾ',
#  'n o s e n t e',
#  'n o s e n t i',
#  'n o g o',
#  'n o n k a',
#  'n o n k o',
#  'n u k a',
#  'n u ː k u',
#  'n o n o',
#  'n o ː ʋ i s',
#  'n u m',
#  'n u n',
#  'n u n k a',
#  'n u n k o',
#  'n u ʋ e ː',
#  'o ː',
#  'o b e d i s e ː',
#  'o b d e s e ː',
#  'o b ɾ e',
#  'o ː b e ɾ',
#  'o b ɾ a s a ː o',
#  'o b ɾ i g a s e ː',
#  'o ː d i a',
#  'o f e ɾ s e ː',
#  'o f e ɾ s i m e n t o',
#  'o f e ɾ a s a ː o',
#  'o f e ɾ s a',
#  'o f e ɾ s o',
#  'o l ʲ o',
#  'o n t a ː',
#  'o n t e',
#  'o ː n t i',
#  'o ː n t a',
#  'o ɾ a t o ː ɾ i a',
#  'o ɾ d i n a ː',
#  'o ɾ t e l a ː o',
#  'o ɾ ʋ a i',
#  'o ɾ a ʋ a i',
#  'o t ɾ o',
#  'o u t ɾ e ː',
#  'o u ɾ a',
#  'o ː ɾ u',
#  'o u ʋ i d a',
#  'o ʋ i d o',
#  'o ʋ i d a',
#  'o ʋ e ʎ o',
#  'p a d a s o',
#  'p a d a s',
#  'p a d a s',
#  'p a d i s e ː',
#  'p a l a ː ʋ e ɾ',
#  'p a ː l ʋ e ɾ',
#  'p a ː l ʋ ɾ a',
#  'p a m p e ɾ l a ː o',
#  'p a n',
#  'p a n k a ː d e ː',
#  'p a n k a d o',
#  'p a ɲ a ː',
#  'p a p i a ː',
#  'p a ɾ',
#  'p a ɾ s a ɾ i a',
#  'p a ɾ i d u ɾ a',
#  'p a ɾ e n t e s k a',
#  'p a ɾ p o ɾ a',
#  'p a ɾ k e',
#  'p a ɾ k i',
#  'p a ː ɾ t e i',
#  'p a s a ː',
#  'p a s e n s i a',
#  'p a s t e m p o',
#  'p a t e k a',
#  'p a ʋ i',
#  'p e ː s i',
#  'p e ː z i',
#  'p e d ɾ e d ̠ ʒ a ː',
#  'p e d ɾ e j a ː',
#  'p e d ɾ i a ː',
#  'p e i',
#  'p e ː l i',
#  'p e l o',
#  'p e l o u ɾ',
#  'p e n e ɾ a ː',
#  'p e k i n i n o',
#  'p e ɾ d a ː',
#  'p e ɾ d o ʋ a ː',
#  'p e ɾ f e i t a d o',
#  'p e ɾ i g ɾ e n e s a ː o',
#  'p e ɾ l a',
#  'p e ɾ m i t ː a ː',
#  'p e ɾ s e g u a i s a ː o',
#  'p e ɾ s u a i d i ɾ',
#  'p e ɾ t ɾ u ʋ a ː',
#  'p e s o ː a',
#  'p e a z o n',
#  'p e s a ː o',
#  'p e s a n',
#  'p e ː s t i a',
#  'p e ː t o',
#  'p i a d a d e',
#  'p i a d o z o',
#  'p i d o z o',
#  'p i d e ː',
#  'p i n d u ɾ a ː',
#  'p i n d ɾ a d o',
#  'p i ɲ o ɾ',
#  'p i ɾ i g o',
#  'p i ɾ e g o z o',
#  'p i s k o ː s',
#  'p l a g a',
#  'p l a ː g u',
#  'p l a n',
#  'p l a ː n t ̠ ʃ e ː',
#  'p l a n e ː t e ː',
#  'p l e n i d a ː o',
#  'p o ː k o',
#  'p o d e ː ɾ a',
#  'p o ː d e z e ɾ',
#  'p o ː d i z e ɾ',
#  'p o ə e',
#  'p o j',
#  'p o ɾ k a d a d e',
#  'p o s e b e ː',
#  'p o s i b e ː',
#  'p o s   s u i b e ː',
#  'p o ː s i a',
#  'p o u t ̠ ʃ e s',
#  'p o ː u t ̠ ʃ i s',
#  'p o ʋ o s a ː o',
#  'p o ʋ e z a n',
#  'p ɾ a n d e ː',
#  'p ɾ a n t a',
#  'p ɾ a t o',
#  'p ɾ a z e ɾ o',
#  'p ɾ a z e i ɾ o',
#  'p ɾ e n d e ː',
#  'p ɾ e n d a ː',
#  'p ɾ a n d e ː',
#  'p ɾ e n d o',
#  'p ɾ e n d a ː',
#  'p ɾ e ː ɲ a',
#  'p ɾ e ɲ e',
#  'p ɾ e n s a',
#  'p ɾ e n s o',
#  'p ɾ e z a',
#  'p ɾ e z o   k a z a',
#  'p ɾ e z e ː n s i a',
#  'p ɾ e z e ː n s i',
#  'p ɾ e z o',
#  'p ɾ e z o',
#  'p ɾ i m e t e ː',
#  'p ɾ i m i t e ː',
#  'p ɾ i m i t a ː',
#  'p ɾ e m i t i d o',
#  'p ɾ i n s e ː z e ː',
#  'p ɾ i n s i p a l i d a d o',
#  'p ɾ i n s p o',
#  'p ɾ e n s p o',
#  'p ɾ i ʋ i l e ː z i a',
#  'p ɾ i ʋ i l e ː z e ː',
#  'p ɾ o f e s a ː o',
#  'p ɾ o f u n d u ɾ a',
#  'p ɾ o f e s i a ː',
#  'p ɾ o f e t o',
#  'p ɾ o ː p i',
#  'p ɾ o ː z i m o',
#  'p ɾ o ː z i m o',
#  'p ɾ o z m o',
#  'p ɾ o ː z m i',
#  'p ɾ o ʋ e ː j t a',
#  'p ɾ o ʋ e i t a ː',
#  'p ɾ u ʋ e i t a ː',
#  'p ɾ u f i a',
#  'p ɾ o f i a',
#  'p ɾ u g u n t a',
#  'p ɾ u n t a',
#  'p ɾ u n t e ː',
#  'p ɾ u n t o',
#  'p ɾ u ʋ a ː',
#  'p ɾ o u ʋ a ː',
#  'p u s a ː',
#  'p u z a ː',
#  'k u a d ɾ i l a',
#  'k u a ː ɾ t ɾ i m o',
#  'k u a ː t o ɾ',
#  'k e m',
#  'k e m a d u ɾ a',
#  'k e ɲ a ː o',
#  'k i ɲ a',
#  'k e r e ː',
#  'k e ɾ e n d o m e n t e',
#  'k e ɾ a n d o m e n t e',
#  'k e ɾ e ɾ',
#  'k e ɾ i a',
#  'k e r i a',
#  'k e s a d o ɾ',
#  'k e t a n t o',
#  'k u t a n t o',
#  'k u o ɾ e n t a',
#  'r a n k a ː',
#  'r a n t ̠ ʃ a ː',
#  'r a s t a ː',
#  'r e b e l d o',
#  'r e b e l o z o',
#  'r e s i a',
#  'r e s i a ː',
#  'r e k o m p e n s a ː o',
#  'r e d a ː',
#  'r e f e n s a',
#  'r e f e n s i a',
#  'r e f u d ̠ ʒ o',
#  'r e d ̠ ʒ i s t ɾ a s a ː o',
#  'r e g o l a ː',
#  'r e n d a ː',
#  'r e p e n d i m e n t o',
#  'r e p e n t a s a ː o',
#  'r e p o s t a ː',
#  'r e p ɾ e n d e',
#  'r e k e d a s a ː o',
#  'r e z g e t o',
#  'r e z o l ʋ a ː',
#  'r e s p e i t a d o',
#  'r e s p e ː t o',
#  'r e s p o n s i b i l i d a d e',
#  'r e s t a n t o',
#  'r e ʃ i n o l',
#  'r e z a ː o',
#  'r e z a n',
#  'r e ʋ o l a ː',
#  'r i u',
#  'r o ː l a',
#  'r o m p a ː',
#  'r o n t ̠ ʃ a ː',
#  'r u b a ː',
#  'r u d e l a',
#  'r u i n o',
#  'r u ʋ i ː n a',
#  'r u ʋ i n a s a ː o',
#  'r u i n a ː',
#  'r u ʋ i n a ː',
#  'r u m p e ː',
#  'r u ʋ a',
#  's a b e ɾ o z o',
#  's a b a ɾ o z o',
#  's a b ɾ o z o',
#  's a i ɲ o',
#  's a l u t a s a ː o',
#  's a n d e ː',
#  's a n d a ː',
#  's a n t i l d a d e',
#  's a ɾ a ː',
#  's a ɾ a d o',
#  's a t i s f a z i d o',
#  's a u d i s a ː o',
#  's a u ː d o',
#  's a u d o   d i a',
#  's e g e n t e',
#  's e g u n t e',
#  's e g i n d o',
#  's e g u ɾ a d o m e n t e',
#  's e i z e n t a',
#  's e i t e',
#  's e m a ʎ a n s a',
#  's e m e i a n s e ː',
#  's e m e n t ɾ i a',
#  's e n',
#  's e n a n',
#  's e ɲ o ɾ i s',
#  's e n t e n s i a',
#  's e p e ɾ a ː',
#  's e p a ɾ a s a ː o',
#  's e ɾ i o z o',
#  's e ː s',
#  's e ʋ e',
#  's i m i a ː',
#  's i m p l e',
#  's i m p l o',
#  's i ɲ a ː ɾ e ː',
#  's i n t e ː',
#  's i o m e',
#  's i s t e ː',
#  's o ː b ɾ i',
#  's o ː b e ɾ',
#  's o s i a d a d e',
#  's o k o ɾ a ː',
#  's o j t a ː',
#  's o l e m n o',
#  's o m b ɾ e ː',
#  's o ː m b e ɾ',
#  's o n e n t o',
#  's u b e ː',
#  's o u b e ː',
#  's u b i a ː',
#  's u b t o m e n t e',
#  's u ː k a ɾ',
#  's u f ɾ i',
#  's u f ɾ a d o ɾ',
#  's u d ̠ ʒ a z a',
#  's u m a n a',
#  's u m a n e ː',
#  's u p e ɾ e m o',
#  's u z a z o',
#  's u s p i ɾ a',
#  's u ʋ a ː',
#  't e l e g ɾ a m o',
#  't e ʎ a d a',
#  't e m a ɾ o',
#  't e n ɾ o',
#  't e ɾ i ʋ e l',
#  't i ɾ n i a',
#  't i r a ː',
#  't o p a ː s',
#  't o ɾ t i l',
#  't o ɾ n o',
#  't ɾ a d u s e ː',
#  't ɾ a i d o',
#  't ɾ a n z g ɾ e s a ː',
#  't ɾ a p a ː',
#  't ɾ a ʋ e ʎ o',
#  't ɾ a ʋ a d ̠ ʒ o',
#  't ɾ a ʋ a i',
#  't ɾ a ʋ i a',
#  't ɾ a ʋ a ʎ a ː',
#  't ɾ a ʋ a l ʲ a ː',
#  't ɾ a ʋ e d ̠ ʒ a ː',
#  't ɾ a ʋ e l i a ː',
#  't ɾ a ʋ i a ː',
#  't ɾ e ː m e ː',
#  't ɾ e ʋ e s a d o',
#  't ɾ e ʋ e z a d o',
#  'a r e ʋ e z a d o',
#  't ɾ i b u l a ː',
#  't ɾ i m i',
#  't ɾ i n i d a d e',
#  't ɾ i n t e ː',
#  't ɾ i o ː m f a',
#  't ɾ i o m p l i a n t e',
#  't ɾ i s t e ː z e ː',
#  't ɾ o ʋ a',
#  't ɾ u ʋ a ː',
#  't ɾ o k a m e n t o',
#  't ɾ o m b e t o',
#  't ɾ u m b e t e ː',
#  't ɾ u z a m e n t o',
#  'u n d ̠ ʒ i a ː',
#  'u ɾ ʋ i s',
#  'ʋ a d a d e',
#  'ʋ a l a n t e',
#  'ʋ a l i a ː',
#  'ʋ a n d a',
#  'ʋ a t ː i',
#  'ʋ e n s a',
#  'ʋ e n k a ː',
#  'ʋ e ɾ d e d e i ɾ o',
#  'ʋ e ː s p e ɾ',
#  'ʋ i d o',
#  'ʋ i g a ː ɾ i',
#  'ʋ i d ̠ ʒ i l',
#  'ʋ i n ə',
#  'ʋ i n d o',
#  'ʋ i n t o ː ɾ e ː',
#  'ʋ i n t e ɾ o z o',
#  'ʋ i n t ɾ o z o',
#  'ʋ i r a ː',
#  'ʋ i s t e ː',
#  'ʋ i s t a ː',
#  'ʋ i z i a',
#  'ʋ i z i a ː']

# %% [markdown]
# # Consonant Stats

# %%
word_list = [re.sub("(?<=[aeiout]) ː", "ː", i) for i in word_list]
word_list = [re.sub("(?<=[nl]) ʲ", "ʲ", i) for i in word_list]
word_list = [re.sub("d ̠ ʒ", "d̠ʒ", i) for i in word_list]
word_list = [re.sub("t ̠ ʃ", "t̠ʃ", i) for i in word_list]
word_list = [re.sub("^", " ", i) for i in word_list]
word_list = [re.sub("$", " ", i) for i in word_list]

word_list[0:10]
# Out:
# [' a b a s o ',
#  ' a b e ɾ s aː ',
#  ' a b e ɾ s aː ',
#  ' a b u ɾ s aː ',
#  ' a b u ɾ s eː ',
#  ' a b o ɾ s i d o ',
#  ' a b s e n s a ',
#  ' a k aː ',
#  ' a s o ɾ a g e ',
#  ' a d eː o ']

# %%
word_list_split = [i.split(" ") for i in word_list]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split = [x for x in word_list_split if x]
vowel_punct = ["a","aː","e","eː","i","iː","o","oː","u","uː","ə","-"]
word_list_split = [e for e in word_list_split if e not in vowel_punct]

# %% [markdown]
# ## Total consonant stats

# %%
counts = Counter(word_list_split)
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df.columns = ["IPA", "count"]
df = df.sort_values(by=["count"],ascending=False).reset_index(drop=True)
df
# Out:
#     IPA  count
# 0     ɾ    485
# 1     s    389
# 2     d    322
# 3     n    316
# 4     t    273
# 5     m    233
# 6     p    206
# 7     k    201
# 8     l    159
# 9     ʋ    129
# 10    z    121
# 11    f    105
# 12    b     95
# 13    g     81
# 14    r     63
# 15  d̠ʒ     60
# 16    ɲ     22
# 17  t̠ʃ     19
# 18    ʎ     18
# 19    j     15
# 20   lʲ      8
# 21   tː      7
# 22    ʃ      5
# 23   nʲ      1

# %% [markdown]
# ## Words with consonant stats

# %%
IPA_list = list(df["IPA"])
in_word_list = []
for word in IPA_list:
    word_search = " "+ word + " "
    matches = len([match for match in word_list if word_search in match])
    in_word_list.append(matches)
df["word_count"] = in_word_list
df["IPA_count_label"] = df["IPA"] + " : " + df["count"].astype(str)
df["IPA_word_count_label"] = df["IPA"] + " : " + df["word_count"].astype(str)
df
# Out:
#     IPA  count  word_count IPA_count_label IPA_word_count_label
# 0     ɾ    485         453         ɾ : 485              ɾ : 453
# 1     s    389         348         s : 389              s : 348
# 2     d    322         275         d : 322              d : 275
# 3     n    316         285         n : 316              n : 285
# 4     t    273         253         t : 273              t : 253
# 5     m    233         224         m : 233              m : 224
# 6     p    206         198         p : 206              p : 198
# 7     k    201         199         k : 201              k : 199
# 8     l    159         158         l : 159              l : 158
# 9     ʋ    129         129         ʋ : 129              ʋ : 129
# 10    z    121         118         z : 121              z : 118
# 11    f    105         104         f : 105              f : 104
# 12    b     95          92          b : 95               b : 92
# 13    g     81          81          g : 81               g : 81
# 14    r     63          63          r : 63               r : 63
# 15  d̠ʒ     60          55        d̠ʒ : 60             d̠ʒ : 55
# 16    ɲ     22          22          ɲ : 22               ɲ : 22
# 17  t̠ʃ     19          19        t̠ʃ : 19             t̠ʃ : 19
# 18    ʎ     18          18          ʎ : 18               ʎ : 18
# 19    j     15          15          j : 15               j : 15
# 20   lʲ      8           8          lʲ : 8               lʲ : 8
# 21   tː      7           7          tː : 7               tː : 7
# 22    ʃ      5           5           ʃ : 5                ʃ : 5
# 23   nʲ      1           1          nʲ : 1               nʲ : 1

# %% [markdown]
# ## Treemap graphs

# %%
labels = list(df["IPA_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()
# Out:
# <ipython-input-8-763c4e79dd80>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot()

# %%
df1 = df.set_index('IPA')
plot = df1.plot.pie(y='count', ylabel='',autopct='%1.1f%%', legend=False, figsize=(14, 14))

# %%
labels = list(df["IPA_word_count_label"])
sizes = list(df["word_count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()
# Out:
# <ipython-input-10-c6dc1fd7c5de>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot()

# %%
df1 = df.set_index('IPA')
plot = df1.plot.pie(y='word_count', ylabel='',autopct='%1.1f%%', legend=False, figsize=(14, 14))

# %% [markdown]
# # CV Stats

# %% [markdown]
# ## Load dataset

# %%
file_name = "crioulo_IPA_CV_compare.csv"

word_df = pd.read_csv(file_name)
word_df
# Out:
#     SriLanka_creole phonetic_transcription phono_TRSVD  phono_CV
# 0             Abaço                  abaso     V.TV.SV   V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV  V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV  V.CVC.CV
# ..              ...                    ...         ...       ...
# 969           Virrá                  ʋiraː       TV.RV     CV.CV
# 970           Vistê                 ʋisteː      TVS.TV    CVC.CV
# 971           vistá                 ʋistaː      TVS.TV    CVC.CV
# 972           Vizia                  ʋizia     TV.SV.V   CV.CV.V
# 973           Viziá                 ʋiziaː     TV.SV.V   CV.CV.V
#
# [974 rows x 4 columns]

# %%
word_list_CV = list(word_df["phono_CV"])
word_list_split = [i.split(".") for i in word_list_CV]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split = [i.split(" ") for i in word_list_split]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split[:] = [x for x in word_list_split if x]

# %% [markdown]
# ## Total syllable stats

# %%
counts = Counter(word_list_split)
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df.columns = ["CV", "count"]
df = df.sort_values(by=["count"],ascending=False).reset_index(drop=True)
df
# Out:
#        CV  count
# 0      CV   1680
# 1     CVC    468
# 2       V    323
# 3     CCV    165
# 4      VC     83
# 5     CVG     47
# 6    CVCV     41
# 7    CCVC     39
# 8       C      8
# 9      VG      7
# 10     VV      5
# 11  CVCVC      5
# 12   CVGC      4
# 13   CVCC      3
# 14  CCVCC      3
# 15   CCVG      2
# 16    VCC      1

# %%
df1 = df.set_index('CV')
plot = df1.plot.pie(y='count', ylabel='',autopct='%1.1f%%', legend=False, figsize=(14, 14))

# %% [markdown]
# ## Words with syllable stats

# %%
word_list_CV = [re.sub("\.", " ", i) for i in word_list_CV]
word_list_CV = [re.sub("^", " ", i) for i in word_list_CV]
word_list_CV = [re.sub("$", " ", i) for i in word_list_CV]

# %%
CV_list = list(df["CV"])
in_word_list = []
for word in CV_list:
    word_search = " "+ word + " "
    matches = len([match for match in word_list_CV if word_search in match])
    in_word_list.append(matches)
df["word_count"] = in_word_list
df["word_count"] = in_word_list
df["CV_count_label"] = df["CV"] + " : " + df["count"].astype(str)
df["CV_word_count_label"] = df["CV"] + " : " + df["word_count"].astype(str)
df
# Out:
#        CV  count  word_count CV_count_label CV_word_count_label
# 0      CV   1680         893      CV : 1680            CV : 893
# 1     CVC    468         400      CVC : 468           CVC : 400
# 2       V    323         289        V : 323             V : 289
# 3     CCV    165         164      CCV : 165           CCV : 164
# 4      VC     83          82        VC : 83             VC : 82
# 5     CVG     47          46       CVG : 47            CVG : 46
# 6    CVCV     41          41      CVCV : 41           CVCV : 41
# 7    CCVC     39          39      CCVC : 39           CCVC : 39
# 8       C      8           8          C : 8               C : 8
# 9      VG      7           7         VG : 7              VG : 7
# 10     VV      5           5         VV : 5              VV : 5
# 11  CVCVC      5           5      CVCVC : 5           CVCVC : 5
# 12   CVGC      4           4       CVGC : 4            CVGC : 4
# 13   CVCC      3           3       CVCC : 3            CVCC : 3
# 14  CCVCC      3           3      CCVCC : 3           CCVCC : 3
# 15   CCVG      2           2       CCVG : 2            CCVG : 2
# 16    VCC      1           1        VCC : 1             VCC : 1

# %% [markdown]
# ## Treemap graphs

# %%
labels = list(df["CV_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()
# Out:
# <ipython-input-18-c65869f2bd7a>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot()

# %%
df1 = df.set_index('CV')
plot = df1.plot.pie(y='count', ylabel='',autopct='%1.1f%%', legend=False, figsize=(14, 14))

# %%
labels = list(df["CV_word_count_label"])
sizes = list(df["word_count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()
# Out:
# <ipython-input-20-8ec5c0d88294>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot()

# %%
df1 = df.set_index('CV')
plot = df1.plot.pie(y='word_count', ylabel='',autopct='%1.1f%%', legend=False, figsize=(14, 14))

# %%
word_df[word_df['phono_CV']=="C"]
# Out:
# Empty DataFrame
# Columns: [SriLanka_creole, phonetic_transcription, phono_TRSVD, phono_CV]
# Index: []

# %%
word_df.to_csv("PhonoCV_Lanka.csv", index = False, header = True)
word_df
# Out:
#     SriLanka_creole phonetic_transcription phono_TRSVD  phono_CV
# 0             Abaço                  abaso     V.TV.SV   V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV  V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV  V.CVC.CV
# ..              ...                    ...         ...       ...
# 969           Virrá                  ʋiraː       TV.RV     CV.CV
# 970           Vistê                 ʋisteː      TVS.TV    CVC.CV
# 971           vistá                 ʋistaː      TVS.TV    CVC.CV
# 972           Vizia                  ʋizia     TV.SV.V   CV.CV.V
# 973           Viziá                 ʋiziaː     TV.SV.V   CV.CV.V
#
# [974 rows x 4 columns]

# %%
word_df_pt = pd.read_csv("PhonoCV_Pt.csv")
#word_df_pt = word_df_pt[["SriLanka_creole","phono_CV"]]
word_df_pt.columns = ["SriLanka_creole","Portuguese_definition","Portuguese_IPA", "phono_CV_pt"]
word_df_pt
# Out:
#     SriLanka_creole Portuguese_definition Portuguese_IPA  phono_CV_pt
# 0             Abaço                abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV
# 1            Aberçà               abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 2            abersà               abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 3            aburçá               abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 4            Aburcé             aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC
# ..              ...                   ...            ...          ...
# 969           Virrá                 virar        vi.ˈɾaɾ       CV.CVC
# 970           Vistê                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 971           vistá                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 972           Vizia                 vigia       vi.ˈʒi.ɐ      CV.CV.V
# 973           Viziá                vigiar      vi.ˈʒi.aɾ     CV.CV.VC
#
# [974 rows x 4 columns]

# %%
word_df = pd.merge(word_df, word_df_pt, on="SriLanka_creole", how='inner')

# %%
word_df
# Out:
#     SriLanka_creole phonetic_transcription phono_TRSVD  phono_CV  \
# 0             Abaço                  abaso     V.TV.SV   V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV  V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV  V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV  V.CVC.CV
# ..              ...                    ...         ...       ...
# 975           Virrá                  ʋiraː       TV.RV     CV.CV
# 976           Vistê                 ʋisteː      TVS.TV    CVC.CV
# 977           vistá                 ʋistaː      TVS.TV    CVC.CV
# 978           Vizia                  ʋizia     TV.SV.V   CV.CV.V
# 979           Viziá                 ʋiziaː     TV.SV.V   CV.CV.V
#
#     Portuguese_definition Portuguese_IPA  phono_CV_pt
# 0                  abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV
# 1                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 2                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 3                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 4               aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC
# ..                    ...            ...          ...
# 975                 virar        vi.ˈɾaɾ       CV.CVC
# 976                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 977                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 978                 vigia       vi.ˈʒi.ɐ      CV.CV.V
# 979                vigiar      vi.ˈʒi.aɾ     CV.CV.VC
#
# [980 rows x 7 columns]

# %%
changes_df = word_df[word_df.phono_CV != word_df.phono_CV_pt]
changes_df
# Out:
#     SriLanka_creole phonetic_transcription phono_TRSVD    phono_CV  \
# 0             Abaço                  abaso     V.TV.SV     V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV    V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV    V.CVC.CV
# ..              ...                    ...         ...         ...
# 974        vintroso               ʋintɾozo  TVR.TRV.SV  CVC.CCV.CV
# 975           Virrá                  ʋiraː       TV.RV       CV.CV
# 976           Vistê                 ʋisteː      TVS.TV      CVC.CV
# 977           vistá                 ʋistaː      TVS.TV      CVC.CV
# 979           Viziá                 ʋiziaː     TV.SV.V     CV.CV.V
#
#     Portuguese_definition Portuguese_IPA  phono_CV_pt
# 0                  abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV
# 1                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 2                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 3                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC
# 4               aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC
# ..                    ...            ...          ...
# 974             venturoso   vẽ.tu.ˈɾo.zu  CV.CV.CV.CV
# 975                 virar        vi.ˈɾaɾ       CV.CVC
# 976                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 977                vestir       vɨʃ.ˈtiɾ      CVC.CVC
# 979                vigiar      vi.ˈʒi.aɾ     CV.CV.VC
#
# [806 rows x 7 columns]

# %%
changes_df['phono_CV_S'] = changes_df['phono_CV'].str.replace('[CV]','')
changes_df
# Out:
# <ipython-input-28-a0749587d6cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changes_df['phono_CV_S'] = changes_df['phono_CV'].str.replace('[CV]','')
#     SriLanka_creole phonetic_transcription phono_TRSVD    phono_CV  \
# 0             Abaço                  abaso     V.TV.SV     V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV    V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV    V.CVC.CV
# ..              ...                    ...         ...         ...
# 974        vintroso               ʋintɾozo  TVR.TRV.SV  CVC.CCV.CV
# 975           Virrá                  ʋiraː       TV.RV       CV.CV
# 976           Vistê                 ʋisteː      TVS.TV      CVC.CV
# 977           vistá                 ʋistaː      TVS.TV      CVC.CV
# 979           Viziá                 ʋiziaː     TV.SV.V     CV.CV.V
#
#     Portuguese_definition Portuguese_IPA  phono_CV_pt phono_CV_S
# 0                  abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV         ..
# 1                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC         ..
# 2                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC         ..
# 3                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC         ..
# 4               aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC         ..
# ..                    ...            ...          ...        ...
# 974             venturoso   vẽ.tu.ˈɾo.zu  CV.CV.CV.CV         ..
# 975                 virar        vi.ˈɾaɾ       CV.CVC          .
# 976                vestir       vɨʃ.ˈtiɾ      CVC.CVC          .
# 977                vestir       vɨʃ.ˈtiɾ      CVC.CVC          .
# 979                vigiar      vi.ˈʒi.aɾ     CV.CV.VC         ..
#
# [806 rows x 8 columns]

# %%
changes_df['phono_CV_S'] = changes_df['phono_CV_S'].str.len()+1
changes_df
# Out:
# <ipython-input-29-f47cd12e207d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changes_df['phono_CV_S'] = changes_df['phono_CV_S'].str.len()+1
#     SriLanka_creole phonetic_transcription phono_TRSVD    phono_CV  \
# 0             Abaço                  abaso     V.TV.SV     V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV    V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV    V.CVC.CV
# ..              ...                    ...         ...         ...
# 974        vintroso               ʋintɾozo  TVR.TRV.SV  CVC.CCV.CV
# 975           Virrá                  ʋiraː       TV.RV       CV.CV
# 976           Vistê                 ʋisteː      TVS.TV      CVC.CV
# 977           vistá                 ʋistaː      TVS.TV      CVC.CV
# 979           Viziá                 ʋiziaː     TV.SV.V     CV.CV.V
#
#     Portuguese_definition Portuguese_IPA  phono_CV_pt  phono_CV_S
# 0                  abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV           3
# 1                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 2                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 3                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 4               aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC           3
# ..                    ...            ...          ...         ...
# 974             venturoso   vẽ.tu.ˈɾo.zu  CV.CV.CV.CV           3
# 975                 virar        vi.ˈɾaɾ       CV.CVC           2
# 976                vestir       vɨʃ.ˈtiɾ      CVC.CVC           2
# 977                vestir       vɨʃ.ˈtiɾ      CVC.CVC           2
# 979                vigiar      vi.ˈʒi.aɾ     CV.CV.VC           3
#
# [806 rows x 8 columns]

# %%
changes_df['phono_CV_pt_S'] = changes_df['phono_CV_pt'].str.replace('[CV]','')

changes_df['phono_CV_pt_S'] = changes_df['phono_CV_pt_S'].str.len()+1
changes_df
# Out:
# <ipython-input-30-2f06ff205e0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changes_df['phono_CV_pt_S'] = changes_df['phono_CV_pt'].str.replace('[CV]','')
# <ipython-input-30-2f06ff205e0e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changes_df['phono_CV_pt_S'] = changes_df['phono_CV_pt_S'].str.len()+1
#     SriLanka_creole phonetic_transcription phono_TRSVD    phono_CV  \
# 0             Abaço                  abaso     V.TV.SV     V.CV.CV
# 1            Aberçà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 2            abersà                abeɾsaː    V.TVR.SV    V.CVC.CV
# 3            aburçá                abuɾsaː    V.TVR.SV    V.CVC.CV
# 4            Aburcé                abuɾseː    V.TVR.SV    V.CVC.CV
# ..              ...                    ...         ...         ...
# 974        vintroso               ʋintɾozo  TVR.TRV.SV  CVC.CCV.CV
# 975           Virrá                  ʋiraː       TV.RV       CV.CV
# 976           Vistê                 ʋisteː      TVS.TV      CVC.CV
# 977           vistá                 ʋistaː      TVS.TV      CVC.CV
# 979           Viziá                 ʋiziaː     TV.SV.V     CV.CV.V
#
#     Portuguese_definition Portuguese_IPA  phono_CV_pt  phono_CV_S  \
# 0                  abaixo      ɐ.ˈbaj.ʃu     V.CVC.CV           3
# 1                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 2                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 3                 abraçar     ɐ.bɾɐ.ˈsaɾ    V.CCV.CVC           3
# 4               aborrecer   ɐ.bu.Rɨ.ˈseɾ  V.CV.CV.CVC           3
# ..                    ...            ...          ...         ...
# 974             venturoso   vẽ.tu.ˈɾo.zu  CV.CV.CV.CV           3
# 975                 virar        vi.ˈɾaɾ       CV.CVC           2
# 976                vestir       vɨʃ.ˈtiɾ      CVC.CVC           2
# 977                vestir       vɨʃ.ˈtiɾ      CVC.CVC           2
# 979                vigiar      vi.ˈʒi.aɾ     CV.CV.VC           3
#
#      phono_CV_pt_S
# 0                3
# 1                3
# 2                3
# 3                3
# 4                4
# ..             ...
# 974              4
# 975              2
# 976              2
# 977              2
# 979              3
#
# [806 rows x 9 columns]

# %%
changes_df = changes_df[changes_df.phono_CV_S != changes_df.phono_CV_pt_S]
changes_df
# Out:
#     SriLanka_creole phonetic_transcription       phono_TRSVD  \
# 4            Aburcé                abuɾseː          V.TVR.SV
# 5          Aborcido               aboɾsido       V.TVR.SV.TV
# 7               Acá                   akaː              V.TV
# 10           Adiôto                adioːto         V.TV.V.TV
# 12      adulteração           adulteɾasaːo  V.TVR.TV.RV.SV.V
# ..              ...                    ...               ...
# 965      Verdedeiro             ʋeɾdedeiɾo     TVR.TV.TVG.RV
# 966          Vésper                ʋeːspeɾ           TVS.TVR
# 967            Vido                   ʋido             TV.TV
# 969           Vigil                ʋid̠ʒil            TV.TVR
# 974        vintroso               ʋintɾozo        TVR.TRV.SV
#
#              phono_CV Portuguese_definition  Portuguese_IPA    phono_CV_pt  \
# 4            V.CVC.CV             aborrecer    ɐ.bu.Rɨ.ˈseɾ    V.CV.CV.CVC
# 5         V.CVC.CV.CV            aborrecido  ɐ.bu.Rɨ.ˈsi.du  V.CV.CV.CV.CV
# 7                V.CV                    cá             ˈka             CV
# 10          V.CV.V.CV                 douto         ˈdow.tu         CVG.CV
# 12   V.CVC.CV.CV.CV.V             adultério  ɐ.duɫ.tˈɛ.ɾi.u  V.CVC.CV.CV.V
# ..                ...                   ...             ...            ...
# 965     CVC.CV.CVG.CV            verdadeiro  vɨɾ.dɐ.ˈdɐj.ɾu  CVC.CV.CVC.CV
# 966           CVC.CVC               véspera      ˈvɛʃ.pɨ.ɾɐ      CVC.CV.CV
# 967             CV.CV                   ver            ˈveɾ            CVC
# 969            CV.CVC               vigília      vi.ˈʒi.ljɐ      CV.CV.CCV
# 974        CVC.CCV.CV             venturoso    vẽ.tu.ˈɾo.zu    CV.CV.CV.CV
#
#      phono_CV_S  phono_CV_pt_S
# 4             3              4
# 5             4              5
# 7             2              1
# 10            4              3
# 12            6              5
# ..          ...            ...
# 965           5              4
# 966           2              3
# 967           2              1
# 969           2              3
# 974           3              4
#
# [458 rows x 9 columns]

# %%
changes_df.to_csv("changes_CV.csv", index = False, header = True)
