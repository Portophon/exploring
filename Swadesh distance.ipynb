# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Packages</a></span></li><li><span><a href="#Load-data-set" data-toc-modified-id="Load-data-set-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Load data set</a></span></li></ul></li><li><span><a href="#Consonant-Stats" data-toc-modified-id="Consonant-Stats-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Consonant Stats</a></span><ul class="toc-item"><li><span><a href="#Total-consonant-stats" data-toc-modified-id="Total-consonant-stats-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Total consonant stats</a></span></li><li><span><a href="#Words-with-consonant-stats" data-toc-modified-id="Words-with-consonant-stats-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Words with consonant stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li><li><span><a href="#CV-Stats" data-toc-modified-id="CV-Stats-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>CV Stats</a></span><ul class="toc-item"><li><span><a href="#Load-dataset" data-toc-modified-id="Load-dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load dataset</a></span></li><li><span><a href="#Total-syllable-stats" data-toc-modified-id="Total-syllable-stats-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Total syllable stats</a></span></li><li><span><a href="#Words-with-syllable-stats" data-toc-modified-id="Words-with-syllable-stats-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Words with syllable stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
import squarify
from abydos.phonetic import *
from abydos.distance import *

# %% [markdown]
# ## Load data set

# %%
file_name = "Swadesh_Timor.csv"

word_df = pd.read_csv(file_name)
word_df
# Out:
#          Language SourceWord  TargetWord SourceWordSyl TargetWordSyl  \
# 0    Timor Pidgin        teŋ         teɾ           teŋ           teɾ
# 1    Timor Pidgin        boŋ        ˈbõ           boŋ          ˈbõ
# 2    Timor Pidgin      ˈuŋwa       ˈu.mɐ        ˈuŋ.wa          u.ma
# 3    Timor Pidgin      ˈuŋwa       ˈu.mɐ        ˈuŋ.wa          u.ma
# 4    Timor Pidgin   alguˈdaŋ  aɫguˈdɐ̃w̃    al.gu.ˈdaŋ  aɫ.gu.ˈdɐ̃w̃
# ..            ...        ...         ...           ...           ...
# 124  Timor Pidgin         ri        ˈʀiɾ            ri          ˈʀiɾ
# 125  Timor Pidgin      ˈkume      kuˈmeɾ        ˈku.me       ku.ˈmeɾ
# 126  Timor Pidgin      ˈkume      kuˈmeɾ        ˈku.me       ku.ˈmeɾ
# 127  Timor Pidgin      ˈsega      ʃɨˈɡaɾ        ˈse.ga       ʃɨ.ˈɡaɾ
# 128  Timor Pidgin      ˈsega      ʃɨˈɡaɾ        ˈse.ga       ʃɨ.ˈɡaɾ
#
#     SourceSyl  TargetSyl PositionSource  PositionTarget       Process  \
# 0          teŋ       teɾ              1               1           NaN
# 1          boŋ      ˈbõ              1               1           NaN
# 2           uŋ         u              1               1  assimilation
# 3           wa        ma              2               2  assimilation
# 4           al        aɫ              1               1           NaN
# ..         ...       ...            ...             ...           ...
# 124         ri      ˈʀiɾ              1               1           NaN
# 125        ˈku        ku              1               1           NaN
# 126         me      ˈmeɾ              2               2           NaN
# 127        ˈse        ʃɨ              1               1           NaN
# 128         ga      ˈɡaɾ              2               2           NaN
#
#     TargetOrthography Translation         Reference  Notes
# 0                 ter    be, have  Baxter1990[7-21]    NaN
# 1                 bom        good  Baxter1990[7-21]    NaN
# 2                 uma      a, one  Baxter1990[7-21]    NaN
# 3                 uma      a, one  Baxter1990[7-21]    NaN
# 4             algodão      cotton  Baxter1990[7-21]    NaN
# ..                ...         ...               ...    ...
# 124               rir       laugh  Baxter1990[7-21]    NaN
# 125             comer         eat  Baxter1990[7-21]    NaN
# 126             comer         eat  Baxter1990[7-21]    NaN
# 127            chegar      arrive  Baxter1990[7-21]    NaN
# 128            chegar      arrive  Baxter1990[7-21]    NaN
#
# [129 rows x 14 columns]

# %%
df = word_df[["SourceWordSyl","TargetWordSyl"]]
df
# Out:
#     SourceWordSyl TargetWordSyl
# 0             teŋ           teɾ
# 1             boŋ          ˈbõ
# 2          ˈuŋ.wa          u.ma
# 3          ˈuŋ.wa          u.ma
# 4      al.gu.ˈdaŋ  aɫ.gu.ˈdɐ̃w̃
# ..            ...           ...
# 124            ri          ˈʀiɾ
# 125        ˈku.me       ku.ˈmeɾ
# 126        ˈku.me       ku.ˈmeɾ
# 127        ˈse.ga       ʃɨ.ˈɡaɾ
# 128        ˈse.ga       ʃɨ.ˈɡaɾ
#
# [129 rows x 2 columns]

# %%
cmp = ALINE()
cmp.alignment('teŋ', 'teɾ')
# Out:
# (50.0, '‖ t e ‖', '‖ t e ‖')

# %%
lst = []

for index, row in df.iterrows():
    print(cmp.alignment(row["SourceWordSyl"], row["TargetWordSyl"]))
    lst.append(cmp.alignment(row["SourceWordSyl"], row["TargetWordSyl"])[0])
# Out:
# (50.0, '‖ t e ‖', '‖ t e ‖')
# (50.0, '‖ b o ‖', '‖ b o ‖')
# (30.0, '‖ uw - a ‖', '‖ u  m a ‖')
# (30.0, '‖ uw - a ‖', '‖ u  m a ‖')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (15.0, 't ‖ u ‖ a', '‖ u ‖ v')
# (15.0, 't ‖ u ‖ a', '‖ u ‖ v')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (23.000000000000004, 'te ‖ r u ‖', '‖ j u ‖')
# (23.000000000000004, 'te ‖ r u ‖', '‖ j u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (15.0, 'd ‖ a ‖', '‖ a ‖')
# (40.0, 'd ‖ e n t ‖ i', '‖ e - t ‖')
# (40.0, 'd ‖ e n t ‖ i', '‖ e - t ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (70.0, '‖ p e s ‖ i', '‖ p e j ‖')
# (70.0, '‖ p e s ‖ i', '‖ p e j ‖')
# (7.5, 'z ‖ i ‖', '‖ o ‖')
# (7.5, 'z ‖ i ‖', '‖ o ‖')
# (55.0, '‖ m i z a ‖', '‖ m i - a ‖')
# (55.0, '‖ m i z a ‖', '‖ m i - a ‖')
# (70.0, '‖ k e z u ‖', '‖ k - j u ‖')
# (70.0, '‖ k e z u ‖', '‖ k - j u ‖')
# (60.0, '‖ s u  ‖ zu', '‖ s uu ‖')
# (60.0, '‖ s u  ‖ zu', '‖ s uu ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (37.5, '‖ f e ‖ ru', '‖ f u ‖')
# (37.5, '‖ f e ‖ ru', '‖ f u ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (50.0, '‖ t u ‖', 'o ‖ t u ‖')
# (50.0, '‖ t u ‖', 'o ‖ t u ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (18.0, '‖ b ‖ ra', '‖ v ‖')
# (18.0, '‖ b ‖ ra', '‖ v ‖')
# (68.0, '‖ b a k ‖ a', '‖ v a k ‖')
# (68.0, '‖ b a k ‖ a', '‖ v a k ‖')
# (48.0, '‖ o b i ‖', '‖ o v i ‖')
# (48.0, '‖ o b i ‖', '‖ o v i ‖')
# (33.0, '‖ b u ‖', 'o ‖ v u ‖')
# (33.0, '‖ b u ‖', 'o ‖ v u ‖')
# (83.0, '‖ n o b u ‖', '‖ n o v u ‖')
# (83.0, '‖ n o b u ‖', '‖ n o v u ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (95.0, '‖ p e t  u ‖', '‖ p e jt u ‖')
# (95.0, '‖ p e t  u ‖', '‖ p e jt u ‖')
# (60.0, '‖ b e s u ‖', '‖ b - j u ‖')
# (60.0, '‖ b e s u ‖', '‖ b - j u ‖')
# (55.0, '‖ l e t  ‖ i', '‖ l - jt ‖')
# (55.0, '‖ l e t  ‖ i', '‖ l - jt ‖')
# (50.0, '‖ m u ‖ jr', '‖ m u ‖')
# (50.0, '‖ m u ‖ jr', '‖ m u ‖')
# (22.5, 'j ‖ u  ‖', '‖ ou ‖')
# (22.5, 'j ‖ u  ‖', '‖ ou ‖')
# (50.0, '‖ d a ‖ di', '‖ d a ‖')
# (50.0, '‖ d a ‖ di', '‖ d a ‖')
# (15.0, 'j ‖ a ‖', '‖ a ‖')
# (15.0, 'j ‖ a ‖', '‖ a ‖')
# (20.0, '‖ a j u ‖', '‖ a - u ‖')
# (20.0, '‖ a j u ‖', '‖ a - u ‖')
# (30.0, '‖ e u ‖', '‖ e w ‖')
# (18.0, '‖ b ‖ os', '‖ v ‖')
# (50.0, '‖ e l ‖ i', '‖ e l ‖')
# (50.0, '‖ e l ‖ i', '‖ e l ‖')
# (35.0, '‖ n ‖ os', '‖ n ‖')
# (18.0, '‖ b ‖ os', '‖ v ‖')
# (85.0, '‖ n u k ‖ a', '‖ n u k ‖')
# (85.0, '‖ n u k ‖ a', '‖ n u k ‖')
# (85.0, '‖ n u n t e ‖', '‖ n w - t a ‖ j')
# (85.0, '‖ n u n t e ‖', '‖ n w - t a ‖ j')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (24.0, '‖ b ‖ e', 'v ‖ j ‖')
# (33.0, '‖ b a ‖ i', '‖ v a ‖ j')
# (75.0, '‖ f a z e ‖', '‖ f - z e ‖')
# (75.0, '‖ f a z e ‖', '‖ f - z e ‖')
# (90.0, '‖ p o d i ‖', '‖ p u d e ‖')
# (90.0, '‖ p o d i ‖', '‖ p u d e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (100.0, '‖ f o g u ‖', '‖ f o g u ‖')
# (100.0, '‖ f o g u ‖', '‖ f o g u ‖')
# (90.0, '‖ p r e nd e ‖', '‖ p - e d  e ‖')
# (90.0, '‖ p r e nd e ‖', '‖ p - e d  e ‖')
# (90.0, '‖ b u s k a ‖', '‖ b u - k a ‖')
# (90.0, '‖ b u s k a ‖', '‖ b u - k a ‖')
# (97.5, '‖ b o t a ‖', '‖ b u t a ‖')
# (97.5, '‖ b o t a ‖', '‖ b u t a ‖')
# (47.5, '‖ s ai ‖', '‖ s i  ‖')
# (47.5, '‖ s ai ‖', '‖ s i  ‖')
# (40.0, '‖ l - a ‖', '‖ l v a ‖')
# (40.0, '‖ l - a ‖', '‖ l v a ‖')
# (90.0, '‖ k o r p u ‖', '‖ k o - p u ‖')
# (90.0, '‖ k o r p u ‖', '‖ k o - p u ‖')
# (15.0, 'r ‖ i ‖', '‖ i ‖')
# (100.0, '‖ k u m e ‖', '‖ k u m e ‖')
# (100.0, '‖ k u m e ‖', '‖ k u m e ‖')
# (15.0, 'seg ‖ a ‖', '‖ a ‖')
# (15.0, 'seg ‖ a ‖', '‖ a ‖')

# %%
df['aline'] = lst
df
# Out:
# <ipython-input-6-32fdf49a304f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['aline'] = lst
#     SourceWordSyl TargetWordSyl  aline
# 0             teŋ           teɾ   50.0
# 1             boŋ          ˈbõ   50.0
# 2          ˈuŋ.wa          u.ma   30.0
# 3          ˈuŋ.wa          u.ma   30.0
# 4      al.gu.ˈdaŋ  aɫ.gu.ˈdɐ̃w̃   92.5
# ..            ...           ...    ...
# 124            ri          ˈʀiɾ   15.0
# 125        ˈku.me       ku.ˈmeɾ  100.0
# 126        ˈku.me       ku.ˈmeɾ  100.0
# 127        ˈse.ga       ʃɨ.ˈɡaɾ   15.0
# 128        ˈse.ga       ʃɨ.ˈɡaɾ   15.0
#
# [129 rows x 3 columns]

# %%
dfalt = word_df[["SourceWord","TargetWord"]]
lst = []

for index, row in dfalt.iterrows():
    print(cmp.alignment(row["SourceWord"], row["TargetWord"]))
    lst.append(cmp.alignment(row["SourceWord"], row["TargetWord"])[0])
# Out:
# (50.0, '‖ t e ‖', '‖ t e ‖')
# (50.0, '‖ b o ‖', '‖ b o ‖')
# (25.0, '‖ uw ‖ a', '‖ u  ‖ m')
# (25.0, '‖ uw ‖ a', '‖ u  ‖ m')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (92.5, '‖ a l g u d a ‖', '‖ a - g u d w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (75.0, '‖ k o r s a ‖', '‖ k u - s w ‖')
# (15.0, 't ‖ u ‖ a', '‖ u ‖ v')
# (15.0, 't ‖ u ‖ a', '‖ u ‖ v')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (47.5, 'ka ‖ t o  ‖ ru', '‖ k ou ‖')
# (23.000000000000004, 'te ‖ r u ‖', '‖ j u ‖')
# (23.000000000000004, 'te ‖ r u ‖', '‖ j u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (67.5, 'nt ‖ i  d u ‖', '‖ ei d u ‖')
# (15.0, 'd ‖ a ‖', '‖ a ‖')
# (40.0, 'd ‖ e n t ‖ i', '‖ e - t ‖')
# (40.0, 'd ‖ e n t ‖ i', '‖ e - t ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (105.0, 'd ‖ u n t a d u ‖', '‖ u - t a d u ‖')
# (70.0, '‖ p e s ‖ i', '‖ p e j ‖')
# (70.0, '‖ p e s ‖ i', '‖ p e j ‖')
# (7.5, 'z ‖ i ‖', '‖ o ‖')
# (7.5, 'z ‖ i ‖', '‖ o ‖')
# (55.0, '‖ m i z a ‖', '‖ m i - a ‖')
# (55.0, '‖ m i z a ‖', '‖ m i - a ‖')
# (70.0, '‖ k e z u ‖', '‖ k - j u ‖')
# (70.0, '‖ k e z u ‖', '‖ k - j u ‖')
# (60.0, '‖ s u  ‖ zu', '‖ s uu ‖')
# (60.0, '‖ s u  ‖ zu', '‖ s uu ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (65.0, '‖ k a r e t ‖ a', '‖ k - - e t ‖')
# (37.5, '‖ f e ‖ ru', '‖ f u ‖')
# (37.5, '‖ f e ‖ ru', '‖ f u ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (65.0, '‖ b a r i g ‖ a', '‖ b - - i g ‖')
# (50.0, '‖ t u ‖', 'o ‖ t u ‖')
# (50.0, '‖ t u ‖', 'o ‖ t u ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (52.5, '‖ k r a n s ‖ a', '‖ k - i - s ‖')
# (18.0, '‖ b ‖ ra', '‖ v ‖')
# (18.0, '‖ b ‖ ra', '‖ v ‖')
# (68.0, '‖ b a k ‖ a', '‖ v a k ‖')
# (68.0, '‖ b a k ‖ a', '‖ v a k ‖')
# (48.0, '‖ o b i ‖', '‖ o v i ‖')
# (48.0, '‖ o b i ‖', '‖ o v i ‖')
# (33.0, '‖ b u ‖', 'o ‖ v u ‖')
# (33.0, '‖ b u ‖', 'o ‖ v u ‖')
# (83.0, '‖ n o b u ‖', '‖ n o v u ‖')
# (83.0, '‖ n o b u ‖', '‖ n o v u ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (65.0, 'a ‖ z  e t ‖ i', '‖ zj - t ‖')
# (95.0, '‖ p e t  u ‖', '‖ p e jt u ‖')
# (95.0, '‖ p e t  u ‖', '‖ p e jt u ‖')
# (60.0, '‖ b e s u ‖', '‖ b - j u ‖')
# (60.0, '‖ b e s u ‖', '‖ b - j u ‖')
# (55.0, '‖ l e t  ‖ i', '‖ l - jt ‖')
# (55.0, '‖ l e t  ‖ i', '‖ l - jt ‖')
# (50.0, '‖ m u ‖ jr', '‖ m u ‖')
# (50.0, '‖ m u ‖ jr', '‖ m u ‖')
# (22.5, 'j ‖ u  ‖', '‖ ou ‖')
# (22.5, 'j ‖ u  ‖', '‖ ou ‖')
# (50.0, '‖ d a ‖ di', '‖ d a ‖')
# (50.0, '‖ d a ‖ di', '‖ d a ‖')
# (15.0, 'j ‖ a ‖', '‖ a ‖')
# (15.0, 'j ‖ a ‖', '‖ a ‖')
# (20.0, '‖ a j u ‖', '‖ a - u ‖')
# (20.0, '‖ a j u ‖', '‖ a - u ‖')
# (30.0, '‖ e u ‖', '‖ e w ‖')
# (18.0, '‖ b ‖ os', '‖ v ‖')
# (50.0, '‖ e l ‖ i', '‖ e l ‖')
# (50.0, '‖ e l ‖ i', '‖ e l ‖')
# (35.0, '‖ n ‖ os', '‖ n ‖')
# (18.0, '‖ b ‖ os', '‖ v ‖')
# (85.0, '‖ n u k ‖ a', '‖ n u k ‖')
# (85.0, '‖ n u k ‖ a', '‖ n u k ‖')
# (85.0, '‖ n u n t e ‖', '‖ n w - t a ‖ j')
# (85.0, '‖ n u n t e ‖', '‖ n w - t a ‖ j')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (100.0, '‖ n u m p o d ‖ i', '‖ n w - p - d ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (155.0, '‖ p u s a b a f u ‖', '‖ p u - a b a f u ‖')
# (24.0, '‖ b ‖ e', 'v ‖ j ‖')
# (33.0, '‖ b a ‖ i', '‖ v a ‖ j')
# (75.0, '‖ f a z e ‖', '‖ f - z e ‖')
# (75.0, '‖ f a z e ‖', '‖ f - z e ‖')
# (90.0, '‖ p o d i ‖', '‖ p u d e ‖')
# (90.0, '‖ p o d i ‖', '‖ p u d e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (95.0, '‖ s a nd e ‖', '‖ s e d  e ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (50.0, '‖ m a ‖ ra', '‖ m a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (75.0, '‖ p a g a ‖', '‖ p - g a ‖')
# (100.0, '‖ f o g u ‖', '‖ f o g u ‖')
# (100.0, '‖ f o g u ‖', '‖ f o g u ‖')
# (90.0, '‖ p r e nd e ‖', '‖ p - e d  e ‖')
# (90.0, '‖ p r e nd e ‖', '‖ p - e d  e ‖')
# (90.0, '‖ b u s k a ‖', '‖ b u - k a ‖')
# (90.0, '‖ b u s k a ‖', '‖ b u - k a ‖')
# (97.5, '‖ b o t a ‖', '‖ b u t a ‖')
# (97.5, '‖ b o t a ‖', '‖ b u t a ‖')
# (47.5, '‖ s ai ‖', '‖ s i  ‖')
# (47.5, '‖ s ai ‖', '‖ s i  ‖')
# (40.0, '‖ l - a ‖', '‖ l v a ‖')
# (40.0, '‖ l - a ‖', '‖ l v a ‖')
# (90.0, '‖ k o r p u ‖', '‖ k o - p u ‖')
# (90.0, '‖ k o r p u ‖', '‖ k o - p u ‖')
# (15.0, 'r ‖ i ‖', '‖ i ‖')
# (100.0, '‖ k u m e ‖', '‖ k u m e ‖')
# (100.0, '‖ k u m e ‖', '‖ k u m e ‖')
# (15.0, 'seg ‖ a ‖', '‖ a ‖')
# (15.0, 'seg ‖ a ‖', '‖ a ‖')

# %%
df['aline2'] = lst
df
# Out:
# <ipython-input-8-09d5f0a05df8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['aline2'] = lst
#     SourceWordSyl TargetWordSyl  aline  aline2
# 0             teŋ           teɾ   50.0    50.0
# 1             boŋ          ˈbõ   50.0    50.0
# 2          ˈuŋ.wa          u.ma   30.0    25.0
# 3          ˈuŋ.wa          u.ma   30.0    25.0
# 4      al.gu.ˈdaŋ  aɫ.gu.ˈdɐ̃w̃   92.5    92.5
# ..            ...           ...    ...     ...
# 124            ri          ˈʀiɾ   15.0    15.0
# 125        ˈku.me       ku.ˈmeɾ  100.0   100.0
# 126        ˈku.me       ku.ˈmeɾ  100.0   100.0
# 127        ˈse.ga       ʃɨ.ˈɡaɾ   15.0    15.0
# 128        ˈse.ga       ʃɨ.ˈɡaɾ   15.0    15.0
#
# [129 rows x 4 columns]

# %%
df = word_df[['SourceSyl','TargetSyl']]
word_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-2c5dc9a65386> in <module>
# ----> 1 df = word_df[['SourceSyl','TargetSyl']]
#       2 word_df.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['SourceSyl'] not in index"
